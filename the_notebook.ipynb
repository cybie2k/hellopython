# %%
from openpyxl import Workbook, load_workbook
import os
from datetime import timedelta,datetime

origcurdir=os.curdir
timelogdir=os.path.join(os.getcwd(),'Time Tracker','timelog')
timelogfile=os.path.join(timelogdir,'TimeLog.xlsx')
print(timelogdir)
print(timelogfile)
print(os.path.normpath(timelogfile))
os.chdir(os.path.normpath(timelogdir))
wb = load_workbook(timelogfile,data_only=True)
ws = wb.worksheets[0]

for row in ws.iter_rows(min_row=1, max_row=1,values_only=True):
    rowheader=list(row)
print(rowheader)
rownum=0
allrows={}
for row in ws.iter_rows(min_row=2,values_only=True):
    rowid=str(rownum)
    rowdata=list(row)
    zippedrow={rowheader:rowdata for rowheader,rowdata in zip(rowheader,rowdata)}
    ##allrows.append(zippedrow)
    edur=zippedrow['Clock Out']-zippedrow['Clock In']
    zippedrow['Event duration']=edur.seconds/3600
    allrows[rowid]=zippedrow
    print (rowid,'=',zippedrow)
  
    ##allrows{rownum}=zippedrow
    rownum+=1
print (allrows)
# Out:
# c:\Users\gregm\dev\hellopython\Time Tracker\timelog
# c:\Users\gregm\dev\hellopython\Time Tracker\timelog\TimeLog.xlsx
# c:\Users\gregm\dev\hellopython\Time Tracker\timelog\TimeLog.xlsx
# ['Clock In', 'Clock Out', 'Task', 'Notes']
# 0 = {'Clock In': datetime.datetime(2022, 1, 1, 15, 27), 'Clock Out': datetime.datetime(2022, 1, 1, 19, 30), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.05}
# 1 = {'Clock In': datetime.datetime(2022, 1, 1, 19, 30), 'Clock Out': datetime.datetime(2022, 1, 1, 20, 30), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 2 = {'Clock In': datetime.datetime(2022, 1, 1, 20, 30), 'Clock Out': datetime.datetime(2022, 1, 2, 0, 41), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.183333333333334}
# 3 = {'Clock In': datetime.datetime(2022, 1, 3, 10, 56), 'Clock Out': datetime.datetime(2022, 1, 3, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.066666666666667}
# 4 = {'Clock In': datetime.datetime(2022, 1, 3, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 3, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 5 = {'Clock In': datetime.datetime(2022, 1, 3, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 3, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 6 = {'Clock In': datetime.datetime(2022, 1, 3, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 3, 18, 20), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.3333333333333335}
# 7 = {'Clock In': datetime.datetime(2022, 1, 3, 18, 20), 'Clock Out': datetime.datetime(2022, 1, 3, 19, 17), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.95}
# 8 = {'Clock In': datetime.datetime(2022, 1, 3, 19, 17), 'Clock Out': datetime.datetime(2022, 1, 3, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.7166666666666666}
# 9 = {'Clock In': datetime.datetime(2022, 1, 3, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 3, 22, 3), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.05}
# 10 = {'Clock In': datetime.datetime(2022, 1, 4, 10, 58), 'Clock Out': datetime.datetime(2022, 1, 4, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.033333333333333}
# 11 = {'Clock In': datetime.datetime(2022, 1, 4, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 4, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 12 = {'Clock In': datetime.datetime(2022, 1, 4, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 4, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 13 = {'Clock In': datetime.datetime(2022, 1, 4, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 4, 18, 6), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.1}
# 14 = {'Clock In': datetime.datetime(2022, 1, 4, 18, 6), 'Clock Out': datetime.datetime(2022, 1, 4, 19, 4), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9666666666666667}
# 15 = {'Clock In': datetime.datetime(2022, 1, 4, 19, 4), 'Clock Out': datetime.datetime(2022, 1, 4, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.9333333333333333}
# 16 = {'Clock In': datetime.datetime(2022, 1, 4, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 4, 22, 14), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.2333333333333334}
# 17 = {'Clock In': datetime.datetime(2022, 1, 5, 11, 5), 'Clock Out': datetime.datetime(2022, 1, 5, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.9166666666666667}
# 18 = {'Clock In': datetime.datetime(2022, 1, 5, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 5, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 19 = {'Clock In': datetime.datetime(2022, 1, 5, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 5, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 20 = {'Clock In': datetime.datetime(2022, 1, 5, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 5, 18, 18), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.3}
# 21 = {'Clock In': datetime.datetime(2022, 1, 5, 18, 18), 'Clock Out': datetime.datetime(2022, 1, 5, 19, 18), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.0}
# 22 = {'Clock In': datetime.datetime(2022, 1, 5, 19, 18), 'Clock Out': datetime.datetime(2022, 1, 5, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.7}
# 23 = {'Clock In': datetime.datetime(2022, 1, 5, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 5, 22, 35), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5833333333333333}
# 24 = {'Clock In': datetime.datetime(2022, 1, 6, 12, 53), 'Clock Out': datetime.datetime(2022, 1, 6, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.1166666666666667}
# 25 = {'Clock In': datetime.datetime(2022, 1, 6, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 6, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 26 = {'Clock In': datetime.datetime(2022, 1, 6, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 6, 17, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 27 = {'Clock In': datetime.datetime(2022, 1, 6, 17, 0), 'Clock Out': datetime.datetime(2022, 1, 6, 18, 21), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.35}
# 28 = {'Clock In': datetime.datetime(2022, 1, 6, 18, 21), 'Clock Out': datetime.datetime(2022, 1, 6, 19, 17), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9333333333333333}
# 29 = {'Clock In': datetime.datetime(2022, 1, 6, 19, 17), 'Clock Out': datetime.datetime(2022, 1, 6, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.7166666666666666}
# 30 = {'Clock In': datetime.datetime(2022, 1, 6, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 6, 22, 7), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.1166666666666667}
# 31 = {'Clock In': datetime.datetime(2022, 1, 7, 15, 26), 'Clock Out': datetime.datetime(2022, 1, 7, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5666666666666667}
# 32 = {'Clock In': datetime.datetime(2022, 1, 7, 17, 0), 'Clock Out': datetime.datetime(2022, 1, 7, 18, 44), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.7333333333333334}
# 33 = {'Clock In': datetime.datetime(2022, 1, 7, 18, 44), 'Clock Out': datetime.datetime(2022, 1, 7, 19, 40), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9333333333333333}
# 34 = {'Clock In': datetime.datetime(2022, 1, 7, 19, 40), 'Clock Out': datetime.datetime(2022, 1, 8, 0, 30), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.833333333333333}
# 35 = {'Clock In': datetime.datetime(2022, 1, 10, 15, 26), 'Clock Out': datetime.datetime(2022, 1, 10, 18, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.566666666666667}
# 36 = {'Clock In': datetime.datetime(2022, 1, 10, 18, 0), 'Clock Out': datetime.datetime(2022, 1, 10, 18, 40), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 0.6666666666666666}
# 37 = {'Clock In': datetime.datetime(2022, 1, 10, 18, 40), 'Clock Out': datetime.datetime(2022, 1, 10, 19, 40), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.0}
# 38 = {'Clock In': datetime.datetime(2022, 1, 10, 19, 40), 'Clock Out': datetime.datetime(2022, 1, 11, 0, 30), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.833333333333333}
# 39 = {'Clock In': datetime.datetime(2022, 1, 11, 12, 56), 'Clock Out': datetime.datetime(2022, 1, 11, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0666666666666667}
# 40 = {'Clock In': datetime.datetime(2022, 1, 11, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 11, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 41 = {'Clock In': datetime.datetime(2022, 1, 11, 17, 0), 'Clock Out': datetime.datetime(2022, 1, 11, 18, 20), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.3333333333333333}
# 42 = {'Clock In': datetime.datetime(2022, 1, 11, 18, 20), 'Clock Out': datetime.datetime(2022, 1, 11, 19, 19), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9833333333333333}
# 43 = {'Clock In': datetime.datetime(2022, 1, 11, 19, 19), 'Clock Out': datetime.datetime(2022, 1, 11, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.6833333333333333}
# 44 = {'Clock In': datetime.datetime(2022, 1, 11, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 11, 22, 56), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.9333333333333333}
# 45 = {'Clock In': datetime.datetime(2022, 1, 12, 15, 28), 'Clock Out': datetime.datetime(2022, 1, 12, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.5333333333333333}
# 46 = {'Clock In': datetime.datetime(2022, 1, 12, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 12, 18, 24), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.4}
# 47 = {'Clock In': datetime.datetime(2022, 1, 12, 18, 24), 'Clock Out': datetime.datetime(2022, 1, 12, 19, 25), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.0166666666666666}
# 48 = {'Clock In': datetime.datetime(2022, 1, 12, 19, 25), 'Clock Out': datetime.datetime(2022, 1, 13, 0, 31), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 5.1}
# 49 = {'Clock In': datetime.datetime(2022, 1, 25, 10, 58), 'Clock Out': datetime.datetime(2022, 1, 25, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.033333333333333}
# 50 = {'Clock In': datetime.datetime(2022, 1, 25, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 25, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 51 = {'Clock In': datetime.datetime(2022, 1, 25, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 25, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 52 = {'Clock In': datetime.datetime(2022, 1, 25, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 25, 18, 33), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.55}
# 53 = {'Clock In': datetime.datetime(2022, 1, 25, 18, 33), 'Clock Out': datetime.datetime(2022, 1, 25, 19, 30), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.95}
# 54 = {'Clock In': datetime.datetime(2022, 1, 25, 19, 30), 'Clock Out': datetime.datetime(2022, 1, 25, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.5}
# 55 = {'Clock In': datetime.datetime(2022, 1, 25, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 25, 21, 21), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.35}
# 56 = {'Clock In': datetime.datetime(2022, 1, 25, 21, 21), 'Clock Out': datetime.datetime(2022, 1, 25, 22, 2), 'Task': 'Training', 'Notes': None, 'Event duration': 0.6833333333333333}
# 57 = {'Clock In': datetime.datetime(2022, 1, 26, 11, 9), 'Clock Out': datetime.datetime(2022, 1, 26, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.85}
# 58 = {'Clock In': datetime.datetime(2022, 1, 26, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 26, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 59 = {'Clock In': datetime.datetime(2022, 1, 26, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 26, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 60 = {'Clock In': datetime.datetime(2022, 1, 26, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 26, 18, 58), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.966666666666667}
# 61 = {'Clock In': datetime.datetime(2022, 1, 26, 18, 58), 'Clock Out': datetime.datetime(2022, 1, 26, 20, 8), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.1666666666666667}
# 62 = {'Clock In': datetime.datetime(2022, 1, 26, 20, 8), 'Clock Out': datetime.datetime(2022, 1, 26, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 0.8666666666666667}
# 63 = {'Clock In': datetime.datetime(2022, 1, 26, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 26, 22, 2), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0333333333333334}
# 64 = {'Clock In': datetime.datetime(2022, 1, 27, 10, 57), 'Clock Out': datetime.datetime(2022, 1, 27, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.05}
# 65 = {'Clock In': datetime.datetime(2022, 1, 27, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 27, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 66 = {'Clock In': datetime.datetime(2022, 1, 27, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 27, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5}
# 67 = {'Clock In': datetime.datetime(2022, 1, 27, 15, 30), 'Clock Out': datetime.datetime(2022, 1, 27, 16, 0), 'Task': 'Meeting', 'Notes': None, 'Event duration': 0.5}
# 68 = {'Clock In': datetime.datetime(2022, 1, 27, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 27, 19, 13), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.216666666666667}
# 69 = {'Clock In': datetime.datetime(2022, 1, 27, 19, 13), 'Clock Out': datetime.datetime(2022, 1, 27, 20, 16), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.05}
# 70 = {'Clock In': datetime.datetime(2022, 1, 27, 20, 16), 'Clock Out': datetime.datetime(2022, 1, 27, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 0.7333333333333333}
# 71 = {'Clock In': datetime.datetime(2022, 1, 27, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 27, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 72 = {'Clock In': datetime.datetime(2022, 1, 28, 11, 9), 'Clock Out': datetime.datetime(2022, 1, 28, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.85}
# 73 = {'Clock In': datetime.datetime(2022, 1, 28, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 28, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 74 = {'Clock In': datetime.datetime(2022, 1, 28, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 28, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 75 = {'Clock In': datetime.datetime(2022, 1, 28, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 28, 18, 12), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.2}
# 76 = {'Clock In': datetime.datetime(2022, 1, 28, 18, 12), 'Clock Out': datetime.datetime(2022, 1, 28, 19, 10), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9666666666666667}
# 77 = {'Clock In': datetime.datetime(2022, 1, 28, 19, 10), 'Clock Out': datetime.datetime(2022, 1, 28, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.8333333333333333}
# 78 = {'Clock In': datetime.datetime(2022, 1, 28, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 28, 22, 2), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0333333333333334}
# 79 = {'Clock In': datetime.datetime(2022, 1, 29, 15, 24), 'Clock Out': datetime.datetime(2022, 1, 30, 0, 34), 'Task': 'Tickets', 'Notes': None, 'Event duration': 9.166666666666666}
# 80 = {'Clock In': datetime.datetime(2022, 1, 30, 10, 59), 'Clock Out': datetime.datetime(2022, 1, 30, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 11.016666666666667}
# 81 = {'Clock In': datetime.datetime(2022, 1, 31, 10, 57), 'Clock Out': datetime.datetime(2022, 1, 31, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.05}
# 82 = {'Clock In': datetime.datetime(2022, 1, 31, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 31, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 83 = {'Clock In': datetime.datetime(2022, 1, 31, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 31, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 84 = {'Clock In': datetime.datetime(2022, 1, 31, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 31, 18, 6), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.1}
# 85 = {'Clock In': datetime.datetime(2022, 1, 31, 18, 6), 'Clock Out': datetime.datetime(2022, 1, 31, 19, 9), 'Task': 'lunch', 'Notes': None, 'Event duration': 1.05}
# 86 = {'Clock In': datetime.datetime(2022, 1, 31, 19, 9), 'Clock Out': datetime.datetime(2022, 1, 31, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.85}
# 87 = {'Clock In': datetime.datetime(2022, 1, 31, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 31, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 88 = {'Clock In': datetime.datetime(2022, 2, 3, 10, 59), 'Clock Out': datetime.datetime(2022, 2, 3, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0166666666666666}
# 89 = {'Clock In': datetime.datetime(2022, 2, 3, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 3, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 90 = {'Clock In': datetime.datetime(2022, 2, 3, 14, 0), 'Clock Out': datetime.datetime(2022, 2, 3, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 91 = {'Clock In': datetime.datetime(2022, 2, 3, 16, 0), 'Clock Out': datetime.datetime(2022, 2, 3, 18, 44), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.7333333333333334}
# 92 = {'Clock In': datetime.datetime(2022, 2, 3, 18, 44), 'Clock Out': datetime.datetime(2022, 2, 3, 19, 45), 'Task': 'lunch', 'Notes': None, 'Event duration': 1.0166666666666666}
# 93 = {'Clock In': datetime.datetime(2022, 2, 3, 19, 45), 'Clock Out': datetime.datetime(2022, 2, 3, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.25}
# 94 = {'Clock In': datetime.datetime(2022, 2, 3, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 3, 22, 2), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0333333333333334}
# 95 = {'Clock In': datetime.datetime(2022, 2, 4, 11, 1), 'Clock Out': datetime.datetime(2022, 2, 4, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.9833333333333334}
# 96 = {'Clock In': datetime.datetime(2022, 2, 4, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 4, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 97 = {'Clock In': datetime.datetime(2022, 2, 4, 14, 0), 'Clock Out': datetime.datetime(2022, 2, 4, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 98 = {'Clock In': datetime.datetime(2022, 2, 4, 17, 0), 'Clock Out': datetime.datetime(2022, 2, 4, 18, 55), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.9166666666666667}
# 99 = {'Clock In': datetime.datetime(2022, 2, 4, 18, 55), 'Clock Out': datetime.datetime(2022, 2, 4, 19, 54), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9833333333333333}
# 100 = {'Clock In': datetime.datetime(2022, 2, 4, 19, 54), 'Clock Out': datetime.datetime(2022, 2, 4, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.1}
# 101 = {'Clock In': datetime.datetime(2022, 2, 4, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 4, 22, 9), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.15}
# 102 = {'Clock In': datetime.datetime(2022, 2, 5, 15, 26), 'Clock Out': datetime.datetime(2022, 2, 6, 0, 32), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 9.1}
# 103 = {'Clock In': datetime.datetime(2022, 2, 7, 11, 26), 'Clock Out': datetime.datetime(2022, 2, 7, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5666666666666667}
# 104 = {'Clock In': datetime.datetime(2022, 2, 7, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 7, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 105 = {'Clock In': datetime.datetime(2022, 2, 7, 14, 0), 'Clock Out': datetime.datetime(2022, 2, 7, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 106 = {'Clock In': datetime.datetime(2022, 2, 7, 16, 0), 'Clock Out': datetime.datetime(2022, 2, 7, 18, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.0}
# 107 = {'Clock In': datetime.datetime(2022, 2, 7, 18, 30), 'Clock Out': datetime.datetime(2022, 2, 7, 19, 28), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9666666666666667}
# 108 = {'Clock In': datetime.datetime(2022, 2, 7, 19, 28), 'Clock Out': datetime.datetime(2022, 2, 7, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.5333333333333334}
# 109 = {'Clock In': datetime.datetime(2022, 2, 7, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 7, 22, 7), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.1166666666666667}
# 110 = {'Clock In': datetime.datetime(2022, 2, 8, 11, 5), 'Clock Out': datetime.datetime(2022, 2, 8, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.9166666666666667}
# 111 = {'Clock In': datetime.datetime(2022, 2, 8, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 8, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 112 = {'Clock In': datetime.datetime(2022, 2, 8, 14, 0), 'Clock Out': datetime.datetime(2022, 2, 8, 18, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 4.0}
# 113 = {'Clock In': datetime.datetime(2022, 2, 8, 18, 0), 'Clock Out': datetime.datetime(2022, 2, 8, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 114 = {'Clock In': datetime.datetime(2022, 2, 8, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 8, 22, 1), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0166666666666666}
# 115 = {'Clock In': datetime.datetime(2022, 2, 9, 11, 5), 'Clock Out': datetime.datetime(2022, 2, 9, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.9166666666666667}
# 116 = {'Clock In': datetime.datetime(2022, 2, 9, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 9, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 117 = {'Clock In': datetime.datetime(2022, 2, 9, 14, 0), 'Clock Out': datetime.datetime(2022, 2, 9, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 118 = {'Clock In': datetime.datetime(2022, 2, 9, 17, 0), 'Clock Out': datetime.datetime(2022, 2, 9, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 119 = {'Clock In': datetime.datetime(2022, 2, 9, 18, 0), 'Clock Out': datetime.datetime(2022, 2, 9, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 120 = {'Clock In': datetime.datetime(2022, 2, 9, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 9, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 121 = {'Clock In': datetime.datetime(2022, 2, 10, 11, 3), 'Clock Out': datetime.datetime(2022, 2, 10, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.95}
# 122 = {'Clock In': datetime.datetime(2022, 2, 10, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 10, 15, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}
# 123 = {'Clock In': datetime.datetime(2022, 2, 10, 15, 0), 'Clock Out': datetime.datetime(2022, 2, 10, 15, 30), 'Task': 'Meeting', 'Notes': 'File Review', 'Event duration': 0.5}
# 124 = {'Clock In': datetime.datetime(2022, 2, 10, 15, 30), 'Clock Out': datetime.datetime(2022, 2, 10, 16, 0), 'Task': 'Meeting', 'Notes': 'Team meeting', 'Event duration': 0.5}
# 125 = {'Clock In': datetime.datetime(2022, 2, 10, 16, 0), 'Clock Out': datetime.datetime(2022, 2, 10, 17, 3), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.05}
# 126 = {'Clock In': datetime.datetime(2022, 2, 10, 17, 3), 'Clock Out': datetime.datetime(2022, 2, 10, 18, 0), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.95}
# 127 = {'Clock In': datetime.datetime(2022, 2, 10, 18, 0), 'Clock Out': datetime.datetime(2022, 2, 10, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 128 = {'Clock In': datetime.datetime(2022, 2, 10, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 10, 22, 2), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0333333333333334}
# 129 = {'Clock In': datetime.datetime(2022, 2, 11, 11, 6), 'Clock Out': datetime.datetime(2022, 2, 11, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.9}
# 130 = {'Clock In': datetime.datetime(2022, 2, 11, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 11, 17, 14), 'Task': 'Tickets', 'Notes': None, 'Event duration': 4.233333333333333}
# 131 = {'Clock In': datetime.datetime(2022, 2, 11, 17, 14), 'Clock Out': datetime.datetime(2022, 2, 11, 18, 10), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9333333333333333}
# 132 = {'Clock In': datetime.datetime(2022, 2, 11, 18, 10), 'Clock Out': datetime.datetime(2022, 2, 11, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.8333333333333335}
# 133 = {'Clock In': datetime.datetime(2022, 2, 11, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 11, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 134 = {'Clock In': datetime.datetime(2022, 2, 14, 13, 40), 'Clock Out': datetime.datetime(2022, 2, 14, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.8333333333333333}
# 135 = {'Clock In': datetime.datetime(2022, 2, 14, 15, 30), 'Clock Out': datetime.datetime(2022, 2, 14, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5}
# 136 = {'Clock In': datetime.datetime(2022, 2, 14, 17, 0), 'Clock Out': datetime.datetime(2022, 2, 14, 18, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 137 = {'Clock In': datetime.datetime(2022, 2, 14, 18, 0), 'Clock Out': datetime.datetime(2022, 2, 14, 21, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 138 = {'Clock In': datetime.datetime(2022, 2, 14, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 15, 0, 33), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.55}
# 139 = {'Clock In': datetime.datetime(2022, 2, 15, 11, 29), 'Clock Out': datetime.datetime(2022, 2, 15, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5166666666666666}
# 140 = {'Clock In': datetime.datetime(2022, 2, 15, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 15, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 141 = {'Clock In': datetime.datetime(2022, 2, 15, 14, 0), 'Clock Out': datetime.datetime(2022, 2, 15, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 142 = {'Clock In': datetime.datetime(2022, 2, 15, 17, 0), 'Clock Out': datetime.datetime(2022, 2, 15, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 143 = {'Clock In': datetime.datetime(2022, 2, 15, 18, 0), 'Clock Out': datetime.datetime(2022, 2, 15, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 144 = {'Clock In': datetime.datetime(2022, 2, 15, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 15, 22, 3), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.05}
# 145 = {'Clock In': datetime.datetime(2022, 2, 16, 11, 36), 'Clock Out': datetime.datetime(2022, 2, 16, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.4}
# 146 = {'Clock In': datetime.datetime(2022, 2, 16, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 16, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 147 = {'Clock In': datetime.datetime(2022, 2, 16, 14, 0), 'Clock Out': datetime.datetime(2022, 2, 16, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 148 = {'Clock In': datetime.datetime(2022, 2, 16, 17, 0), 'Clock Out': datetime.datetime(2022, 2, 16, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 149 = {'Clock In': datetime.datetime(2022, 2, 16, 18, 0), 'Clock Out': datetime.datetime(2022, 2, 16, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 150 = {'Clock In': datetime.datetime(2022, 2, 16, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 16, 22, 7), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.1166666666666667}
# 151 = {'Clock In': datetime.datetime(2022, 2, 17, 9, 56), 'Clock Out': datetime.datetime(2022, 2, 17, 11, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0666666666666667}
# 152 = {'Clock In': datetime.datetime(2022, 2, 17, 11, 0), 'Clock Out': datetime.datetime(2022, 2, 17, 12, 0), 'Task': 'Tickets', 'Notes': 'meeting cancelled', 'Event duration': 1.0}
# 153 = {'Clock In': datetime.datetime(2022, 2, 17, 12, 0), 'Clock Out': datetime.datetime(2022, 2, 17, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 154 = {'Clock In': datetime.datetime(2022, 2, 17, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 17, 13, 52), 'Task': 'Meeting', 'Notes': 'Coalesce', 'Event duration': 0.8666666666666667}
# 155 = {'Clock In': datetime.datetime(2022, 2, 17, 13, 52), 'Clock Out': datetime.datetime(2022, 2, 17, 14, 5), 'Task': 'Training', 'Notes': None, 'Event duration': 0.21666666666666667}
# 156 = {'Clock In': datetime.datetime(2022, 2, 17, 14, 5), 'Clock Out': datetime.datetime(2022, 2, 17, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.4166666666666667}
# 157 = {'Clock In': datetime.datetime(2022, 2, 17, 15, 30), 'Clock Out': datetime.datetime(2022, 2, 17, 16, 13), 'Task': 'Meeting', 'Notes': None, 'Event duration': 0.7166666666666667}
# 158 = {'Clock In': datetime.datetime(2022, 2, 17, 16, 13), 'Clock Out': datetime.datetime(2022, 2, 17, 17, 5), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.8666666666666667}
# 159 = {'Clock In': datetime.datetime(2022, 2, 17, 17, 5), 'Clock Out': datetime.datetime(2022, 2, 17, 18, 3), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9666666666666667}
# 160 = {'Clock In': datetime.datetime(2022, 2, 17, 18, 3), 'Clock Out': datetime.datetime(2022, 2, 17, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.95}
# 161 = {'Clock In': datetime.datetime(2022, 2, 17, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 17, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 162 = {'Clock In': datetime.datetime(2022, 2, 18, 11, 6), 'Clock Out': datetime.datetime(2022, 2, 18, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.9}
# 163 = {'Clock In': datetime.datetime(2022, 2, 18, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 18, 17, 5), 'Task': 'Tickets', 'Notes': None, 'Event duration': 4.083333333333333}
# 164 = {'Clock In': datetime.datetime(2022, 2, 18, 17, 5), 'Clock Out': datetime.datetime(2022, 2, 18, 18, 4), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 0.9833333333333333}
# 165 = {'Clock In': datetime.datetime(2022, 2, 18, 18, 4), 'Clock Out': datetime.datetime(2022, 2, 18, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.933333333333333}
# 166 = {'Clock In': datetime.datetime(2022, 2, 18, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 18, 22, 5), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0833333333333333}
# 167 = {'Clock In': datetime.datetime(2022, 2, 21, 11, 57), 'Clock Out': datetime.datetime(2022, 2, 21, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.05}
# 168 = {'Clock In': datetime.datetime(2022, 2, 21, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 21, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 169 = {'Clock In': datetime.datetime(2022, 2, 21, 14, 0), 'Clock Out': datetime.datetime(2022, 2, 21, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 170 = {'Clock In': datetime.datetime(2022, 2, 21, 17, 0), 'Clock Out': datetime.datetime(2022, 2, 21, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 171 = {'Clock In': datetime.datetime(2022, 2, 21, 18, 0), 'Clock Out': datetime.datetime(2022, 2, 21, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 172 = {'Clock In': datetime.datetime(2022, 2, 21, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 21, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 173 = {'Clock In': datetime.datetime(2022, 2, 22, 13, 40), 'Clock Out': datetime.datetime(2022, 2, 22, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.8333333333333333}
# 174 = {'Clock In': datetime.datetime(2022, 2, 22, 15, 30), 'Clock Out': datetime.datetime(2022, 2, 22, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5}
# 175 = {'Clock In': datetime.datetime(2022, 2, 22, 17, 0), 'Clock Out': datetime.datetime(2022, 2, 22, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 176 = {'Clock In': datetime.datetime(2022, 2, 22, 18, 0), 'Clock Out': datetime.datetime(2022, 2, 22, 21, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 177 = {'Clock In': datetime.datetime(2022, 2, 22, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 23, 0, 52), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.8666666666666667}
# 178 = {'Clock In': datetime.datetime(2022, 2, 23, 14, 24), 'Clock Out': datetime.datetime(2022, 2, 23, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.1}
# 179 = {'Clock In': datetime.datetime(2022, 2, 23, 15, 30), 'Clock Out': datetime.datetime(2022, 2, 23, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5}
# 180 = {'Clock In': datetime.datetime(2022, 2, 23, 17, 0), 'Clock Out': datetime.datetime(2022, 2, 23, 18, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 181 = {'Clock In': datetime.datetime(2022, 2, 23, 18, 0), 'Clock Out': datetime.datetime(2022, 2, 23, 21, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 182 = {'Clock In': datetime.datetime(2022, 2, 23, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 24, 0, 36), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.6}
# 183 = {'Clock In': datetime.datetime(2022, 2, 24, 11, 26), 'Clock Out': datetime.datetime(2022, 2, 24, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5666666666666667}
# 184 = {'Clock In': datetime.datetime(2022, 2, 24, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 24, 14, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5}
# 185 = {'Clock In': datetime.datetime(2022, 2, 24, 14, 30), 'Clock Out': datetime.datetime(2022, 2, 24, 15, 0), 'Task': 'Meeting', 'Notes': None, 'Event duration': 0.5}
# 186 = {'Clock In': datetime.datetime(2022, 2, 24, 15, 0), 'Clock Out': datetime.datetime(2022, 2, 24, 17, 15), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.25}
# 187 = {'Clock In': datetime.datetime(2022, 2, 24, 17, 15), 'Clock Out': datetime.datetime(2022, 2, 24, 18, 12), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.95}
# 188 = {'Clock In': datetime.datetime(2022, 2, 24, 18, 12), 'Clock Out': datetime.datetime(2022, 2, 24, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.8}
# 189 = {'Clock In': datetime.datetime(2022, 2, 24, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 24, 22, 3), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.05}
# 190 = {'Clock In': datetime.datetime(2022, 2, 25, 12, 39), 'Clock Out': datetime.datetime(2022, 2, 25, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.35}
# 191 = {'Clock In': datetime.datetime(2022, 2, 25, 13, 0), 'Clock Out': datetime.datetime(2022, 2, 25, 17, 13), 'Task': 'Tickets', 'Notes': None, 'Event duration': 4.216666666666667}
# 192 = {'Clock In': datetime.datetime(2022, 2, 25, 17, 13), 'Clock Out': datetime.datetime(2022, 2, 25, 18, 11), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9666666666666667}
# 193 = {'Clock In': datetime.datetime(2022, 2, 25, 18, 11), 'Clock Out': datetime.datetime(2022, 2, 25, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.816666666666667}
# 194 = {'Clock In': datetime.datetime(2022, 2, 25, 21, 0), 'Clock Out': datetime.datetime(2022, 2, 25, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 195 = {'Clock In': datetime.datetime(2022, 3, 1, 10, 59), 'Clock Out': datetime.datetime(2022, 3, 1, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0166666666666666}
# 196 = {'Clock In': datetime.datetime(2022, 3, 1, 13, 0), 'Clock Out': datetime.datetime(2022, 3, 1, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 197 = {'Clock In': datetime.datetime(2022, 3, 1, 14, 0), 'Clock Out': datetime.datetime(2022, 3, 1, 17, 19), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.316666666666667}
# 198 = {'Clock In': datetime.datetime(2022, 3, 1, 17, 19), 'Clock Out': datetime.datetime(2022, 3, 1, 18, 15), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9333333333333333}
# 199 = {'Clock In': datetime.datetime(2022, 3, 1, 18, 15), 'Clock Out': datetime.datetime(2022, 3, 1, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.75}
# 200 = {'Clock In': datetime.datetime(2022, 3, 1, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 1, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 201 = {'Clock In': datetime.datetime(2022, 3, 2, 11, 29), 'Clock Out': datetime.datetime(2022, 3, 2, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5166666666666666}
# 202 = {'Clock In': datetime.datetime(2022, 3, 2, 13, 0), 'Clock Out': datetime.datetime(2022, 3, 2, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 203 = {'Clock In': datetime.datetime(2022, 3, 2, 14, 0), 'Clock Out': datetime.datetime(2022, 3, 2, 17, 8), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.1333333333333333}
# 204 = {'Clock In': datetime.datetime(2022, 3, 2, 17, 8), 'Clock Out': datetime.datetime(2022, 3, 2, 18, 12), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.0666666666666667}
# 205 = {'Clock In': datetime.datetime(2022, 3, 2, 18, 12), 'Clock Out': datetime.datetime(2022, 3, 2, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.8}
# 206 = {'Clock In': datetime.datetime(2022, 3, 2, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 2, 22, 1), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0166666666666666}
# 207 = {'Clock In': datetime.datetime(2022, 3, 3, 11, 35), 'Clock Out': datetime.datetime(2022, 3, 3, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.4166666666666667}
# 208 = {'Clock In': datetime.datetime(2022, 3, 3, 13, 0), 'Clock Out': datetime.datetime(2022, 3, 3, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.5}
# 209 = {'Clock In': datetime.datetime(2022, 3, 3, 15, 30), 'Clock Out': datetime.datetime(2022, 3, 3, 16, 0), 'Task': 'Meeting', 'Notes': None, 'Event duration': 0.5}
# 210 = {'Clock In': datetime.datetime(2022, 3, 3, 16, 0), 'Clock Out': datetime.datetime(2022, 3, 3, 17, 16), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.2666666666666666}
# 211 = {'Clock In': datetime.datetime(2022, 3, 3, 17, 16), 'Clock Out': datetime.datetime(2022, 3, 3, 18, 12), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9333333333333333}
# 212 = {'Clock In': datetime.datetime(2022, 3, 3, 18, 12), 'Clock Out': datetime.datetime(2022, 3, 3, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.8}
# 213 = {'Clock In': datetime.datetime(2022, 3, 3, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 3, 22, 6), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.1}
# 214 = {'Clock In': datetime.datetime(2022, 3, 4, 11, 21), 'Clock Out': datetime.datetime(2022, 3, 4, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.65}
# 215 = {'Clock In': datetime.datetime(2022, 3, 4, 13, 0), 'Clock Out': datetime.datetime(2022, 3, 4, 17, 20), 'Task': 'Tickets', 'Notes': None, 'Event duration': 4.333333333333333}
# 216 = {'Clock In': datetime.datetime(2022, 3, 4, 17, 20), 'Clock Out': datetime.datetime(2022, 3, 4, 18, 22), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.0333333333333334}
# 217 = {'Clock In': datetime.datetime(2022, 3, 4, 18, 22), 'Clock Out': datetime.datetime(2022, 3, 4, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.6333333333333333}
# 218 = {'Clock In': datetime.datetime(2022, 3, 4, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 4, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 219 = {'Clock In': datetime.datetime(2022, 3, 5, 15, 28), 'Clock Out': datetime.datetime(2022, 3, 5, 18, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.533333333333333}
# 220 = {'Clock In': datetime.datetime(2022, 3, 5, 18, 0), 'Clock Out': datetime.datetime(2022, 3, 5, 19, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 221 = {'Clock In': datetime.datetime(2022, 3, 5, 19, 0), 'Clock Out': datetime.datetime(2022, 3, 6, 0, 32), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 5.533333333333333}
# 222 = {'Clock In': datetime.datetime(2022, 3, 6, 11, 0), 'Clock Out': datetime.datetime(2022, 3, 6, 17, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 6.0}
# 223 = {'Clock In': datetime.datetime(2022, 3, 6, 17, 0), 'Clock Out': datetime.datetime(2022, 3, 6, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 224 = {'Clock In': datetime.datetime(2022, 3, 6, 18, 0), 'Clock Out': datetime.datetime(2022, 3, 6, 22, 3), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.05}
# 225 = {'Clock In': datetime.datetime(2022, 3, 7, 11, 16), 'Clock Out': datetime.datetime(2022, 3, 7, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.7333333333333334}
# 226 = {'Clock In': datetime.datetime(2022, 3, 7, 13, 0), 'Clock Out': datetime.datetime(2022, 3, 7, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 227 = {'Clock In': datetime.datetime(2022, 3, 7, 14, 0), 'Clock Out': datetime.datetime(2022, 3, 7, 17, 7), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.1166666666666667}
# 228 = {'Clock In': datetime.datetime(2022, 3, 7, 17, 7), 'Clock Out': datetime.datetime(2022, 3, 7, 18, 6), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9833333333333333}
# 229 = {'Clock In': datetime.datetime(2022, 3, 7, 18, 6), 'Clock Out': datetime.datetime(2022, 3, 7, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.9}
# 230 = {'Clock In': datetime.datetime(2022, 3, 7, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 7, 22, 6), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.1}
# 231 = {'Clock In': datetime.datetime(2022, 3, 10, 12, 59), 'Clock Out': datetime.datetime(2022, 3, 10, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.5166666666666666}
# 232 = {'Clock In': datetime.datetime(2022, 3, 10, 15, 30), 'Clock Out': datetime.datetime(2022, 3, 10, 16, 11), 'Task': 'Meeting', 'Notes': None, 'Event duration': 0.6833333333333333}
# 233 = {'Clock In': datetime.datetime(2022, 3, 10, 16, 11), 'Clock Out': datetime.datetime(2022, 3, 10, 17, 19), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.1333333333333333}
# 234 = {'Clock In': datetime.datetime(2022, 3, 10, 17, 19), 'Clock Out': datetime.datetime(2022, 3, 10, 18, 15), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9333333333333333}
# 235 = {'Clock In': datetime.datetime(2022, 3, 10, 18, 15), 'Clock Out': datetime.datetime(2022, 3, 10, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.75}
# 236 = {'Clock In': datetime.datetime(2022, 3, 10, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 10, 22, 2), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0333333333333334}
# 237 = {'Clock In': datetime.datetime(2022, 3, 11, 11, 32), 'Clock Out': datetime.datetime(2022, 3, 11, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.4666666666666666}
# 238 = {'Clock In': datetime.datetime(2022, 3, 11, 13, 0), 'Clock Out': datetime.datetime(2022, 3, 11, 16, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 239 = {'Clock In': datetime.datetime(2022, 3, 11, 16, 0), 'Clock Out': datetime.datetime(2022, 3, 11, 17, 8), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.1333333333333333}
# 240 = {'Clock In': datetime.datetime(2022, 3, 11, 17, 8), 'Clock Out': datetime.datetime(2022, 3, 11, 18, 1), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.8833333333333333}
# 241 = {'Clock In': datetime.datetime(2022, 3, 11, 18, 1), 'Clock Out': datetime.datetime(2022, 3, 11, 19, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.9833333333333333}
# 242 = {'Clock In': datetime.datetime(2022, 3, 11, 19, 0), 'Clock Out': datetime.datetime(2022, 3, 11, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.0}
# 243 = {'Clock In': datetime.datetime(2022, 3, 11, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 11, 22, 1), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0166666666666666}
# 244 = {'Clock In': datetime.datetime(2022, 3, 12, 15, 29), 'Clock Out': datetime.datetime(2022, 3, 13, 0, 31), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 9.033333333333333}
# 245 = {'Clock In': datetime.datetime(2022, 3, 14, 11, 55), 'Clock Out': datetime.datetime(2022, 3, 14, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0833333333333333}
# 246 = {'Clock In': datetime.datetime(2022, 3, 14, 13, 0), 'Clock Out': datetime.datetime(2022, 3, 14, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 247 = {'Clock In': datetime.datetime(2022, 3, 14, 14, 0), 'Clock Out': datetime.datetime(2022, 3, 14, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 248 = {'Clock In': datetime.datetime(2022, 3, 14, 17, 0), 'Clock Out': datetime.datetime(2022, 3, 14, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 249 = {'Clock In': datetime.datetime(2022, 3, 14, 18, 0), 'Clock Out': datetime.datetime(2022, 3, 14, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 250 = {'Clock In': datetime.datetime(2022, 3, 14, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 14, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 251 = {'Clock In': datetime.datetime(2022, 3, 15, 10, 58), 'Clock Out': datetime.datetime(2022, 3, 15, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.033333333333333}
# 252 = {'Clock In': datetime.datetime(2022, 3, 15, 13, 0), 'Clock Out': datetime.datetime(2022, 3, 15, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 253 = {'Clock In': datetime.datetime(2022, 3, 15, 14, 0), 'Clock Out': datetime.datetime(2022, 3, 15, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 254 = {'Clock In': datetime.datetime(2022, 3, 15, 17, 0), 'Clock Out': datetime.datetime(2022, 3, 15, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 255 = {'Clock In': datetime.datetime(2022, 3, 15, 18, 0), 'Clock Out': datetime.datetime(2022, 3, 15, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 256 = {'Clock In': datetime.datetime(2022, 3, 15, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 15, 22, 4), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0666666666666667}
# 257 = {'Clock In': datetime.datetime(2022, 3, 16, 11, 57), 'Clock Out': datetime.datetime(2022, 3, 16, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.05}
# 258 = {'Clock In': datetime.datetime(2022, 3, 16, 13, 0), 'Clock Out': datetime.datetime(2022, 3, 16, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 259 = {'Clock In': datetime.datetime(2022, 3, 16, 14, 0), 'Clock Out': datetime.datetime(2022, 3, 16, 17, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.0}
# 260 = {'Clock In': datetime.datetime(2022, 3, 16, 17, 0), 'Clock Out': datetime.datetime(2022, 3, 16, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 261 = {'Clock In': datetime.datetime(2022, 3, 16, 18, 0), 'Clock Out': datetime.datetime(2022, 3, 16, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 3.0}
# 262 = {'Clock In': datetime.datetime(2022, 3, 16, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 16, 22, 9), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.15}
# 263 = {'Clock In': datetime.datetime(2022, 3, 17, 13, 3), 'Clock Out': datetime.datetime(2022, 3, 17, 13, 39), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 0.6}
# 264 = {'Clock In': datetime.datetime(2022, 3, 17, 13, 39), 'Clock Out': datetime.datetime(2022, 3, 17, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.85}
# 265 = {'Clock In': datetime.datetime(2022, 3, 17, 15, 30), 'Clock Out': datetime.datetime(2022, 3, 17, 15, 54), 'Task': 'Meeting', 'Notes': None, 'Event duration': 0.4}
# 266 = {'Clock In': datetime.datetime(2022, 3, 17, 15, 54), 'Clock Out': datetime.datetime(2022, 3, 17, 17, 35), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.6833333333333333}
# 267 = {'Clock In': datetime.datetime(2022, 3, 17, 17, 35), 'Clock Out': datetime.datetime(2022, 3, 17, 18, 39), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.0666666666666667}
# 268 = {'Clock In': datetime.datetime(2022, 3, 17, 18, 39), 'Clock Out': datetime.datetime(2022, 3, 17, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.35}
# 269 = {'Clock In': datetime.datetime(2022, 3, 17, 21, 0), 'Clock Out': datetime.datetime(2022, 3, 17, 21, 15), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.25}
# 270 = {'Clock In': datetime.datetime(2022, 3, 17, 21, 15), 'Clock Out': datetime.datetime(2022, 3, 17, 22, 4), 'Task': 'Meeting', 'Notes': 'Watch D&I Meeting video', 'Event duration': 0.8166666666666667}
# 271 = {'Clock In': datetime.datetime(2022, 3, 18, 10, 59), 'Clock Out': datetime.datetime(2022, 3, 18, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0166666666666666}
# ...
# 1074 = {'Clock In': datetime.datetime(2022, 10, 26, 18, 13), 'Clock Out': datetime.datetime(2022, 10, 27, 0, 30), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 6.283333333333333}
# 1075 = {'Clock In': datetime.datetime(2022, 11, 5, 15, 21), 'Clock Out': datetime.datetime(2022, 11, 5, 17, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.65}
# 1076 = {'Clock In': datetime.datetime(2022, 11, 5, 17, 0), 'Clock Out': datetime.datetime(2022, 11, 5, 18, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 1077 = {'Clock In': datetime.datetime(2022, 11, 5, 18, 0), 'Clock Out': datetime.datetime(2022, 11, 6, 0, 31), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 6.516666666666667}
# 1078 = {'Clock In': datetime.datetime(2022, 11, 6, 10, 57), 'Clock Out': datetime.datetime(2022, 11, 6, 22, 3), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 11.1}
# 1079 = {'Clock In': datetime.datetime(2022, 11, 7, 11, 29), 'Clock Out': datetime.datetime(2022, 11, 7, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.5166666666666666}
# 1080 = {'Clock In': datetime.datetime(2022, 11, 7, 13, 0), 'Clock Out': datetime.datetime(2022, 11, 7, 17, 15), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.25}
# 1081 = {'Clock In': datetime.datetime(2022, 11, 7, 17, 15), 'Clock Out': datetime.datetime(2022, 11, 7, 18, 11), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9333333333333333}
# 1082 = {'Clock In': datetime.datetime(2022, 11, 7, 18, 11), 'Clock Out': datetime.datetime(2022, 11, 7, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.816666666666667}
# 1083 = {'Clock In': datetime.datetime(2022, 11, 7, 21, 0), 'Clock Out': datetime.datetime(2022, 11, 7, 22, 3), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.05}
# 1084 = {'Clock In': datetime.datetime(2022, 11, 10, 10, 56), 'Clock Out': datetime.datetime(2022, 11, 10, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.066666666666667}
# 1085 = {'Clock In': datetime.datetime(2022, 11, 10, 13, 0), 'Clock Out': datetime.datetime(2022, 11, 10, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.5}
# 1086 = {'Clock In': datetime.datetime(2022, 11, 10, 15, 30), 'Clock Out': datetime.datetime(2022, 11, 10, 16, 0), 'Task': 'Meeting', 'Notes': None, 'Event duration': 0.5}
# 1087 = {'Clock In': datetime.datetime(2022, 11, 10, 16, 0), 'Clock Out': datetime.datetime(2022, 11, 10, 17, 6), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.1}
# 1088 = {'Clock In': datetime.datetime(2022, 11, 10, 17, 6), 'Clock Out': datetime.datetime(2022, 11, 10, 18, 3), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.95}
# 1089 = {'Clock In': datetime.datetime(2022, 11, 10, 18, 3), 'Clock Out': datetime.datetime(2022, 11, 10, 20, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.95}
# 1090 = {'Clock In': datetime.datetime(2022, 11, 10, 20, 0), 'Clock Out': datetime.datetime(2022, 11, 10, 22, 4), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.066666666666667}
# 1091 = {'Clock In': datetime.datetime(2022, 11, 11, 12, 59), 'Clock Out': datetime.datetime(2022, 11, 11, 17, 40), 'Task': 'Tickets', 'Notes': None, 'Event duration': 4.683333333333334}
# 1092 = {'Clock In': datetime.datetime(2022, 11, 11, 17, 40), 'Clock Out': datetime.datetime(2022, 11, 11, 18, 32), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.8666666666666667}
# 1093 = {'Clock In': datetime.datetime(2022, 11, 11, 18, 32), 'Clock Out': datetime.datetime(2022, 11, 11, 20, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.4666666666666666}
# 1094 = {'Clock In': datetime.datetime(2022, 11, 11, 20, 0), 'Clock Out': datetime.datetime(2022, 11, 11, 22, 18), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.3}
# 1095 = {'Clock In': datetime.datetime(2022, 11, 12, 15, 28), 'Clock Out': datetime.datetime(2022, 11, 12, 18, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.533333333333333}
# 1096 = {'Clock In': datetime.datetime(2022, 11, 12, 18, 0), 'Clock Out': datetime.datetime(2022, 11, 12, 19, 0), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}
# 1097 = {'Clock In': datetime.datetime(2022, 11, 12, 19, 0), 'Clock Out': datetime.datetime(2022, 11, 13, 0, 39), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 5.65}
# 1098 = {'Clock In': datetime.datetime(2022, 11, 14, 11, 8), 'Clock Out': datetime.datetime(2022, 11, 14, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.8666666666666667}
# 1099 = {'Clock In': datetime.datetime(2022, 11, 14, 13, 0), 'Clock Out': datetime.datetime(2022, 11, 14, 17, 8), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.133333333333334}
# 1100 = {'Clock In': datetime.datetime(2022, 11, 14, 17, 8), 'Clock Out': datetime.datetime(2022, 11, 14, 18, 0), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.8666666666666667}
# 1101 = {'Clock In': datetime.datetime(2022, 11, 14, 18, 0), 'Clock Out': datetime.datetime(2022, 11, 14, 20, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.0}
# 1102 = {'Clock In': datetime.datetime(2022, 11, 14, 20, 0), 'Clock Out': datetime.datetime(2022, 11, 14, 22, 4), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.066666666666667}
# 1103 = {'Clock In': datetime.datetime(2022, 11, 15, 11, 15), 'Clock Out': datetime.datetime(2022, 11, 15, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.75}
# 1104 = {'Clock In': datetime.datetime(2022, 11, 15, 13, 0), 'Clock Out': datetime.datetime(2022, 11, 15, 17, 17), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.283333333333333}
# 1105 = {'Clock In': datetime.datetime(2022, 11, 15, 17, 17), 'Clock Out': datetime.datetime(2022, 11, 15, 18, 13), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9333333333333333}
# 1106 = {'Clock In': datetime.datetime(2022, 11, 15, 18, 13), 'Clock Out': datetime.datetime(2022, 11, 15, 20, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.7833333333333334}
# 1107 = {'Clock In': datetime.datetime(2022, 11, 15, 20, 0), 'Clock Out': datetime.datetime(2022, 11, 15, 22, 6), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.1}
# 1108 = {'Clock In': datetime.datetime(2022, 11, 16, 11, 2), 'Clock Out': datetime.datetime(2022, 11, 16, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.9666666666666666}
# 1109 = {'Clock In': datetime.datetime(2022, 11, 16, 13, 0), 'Clock Out': datetime.datetime(2022, 11, 16, 17, 16), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.266666666666667}
# 1110 = {'Clock In': datetime.datetime(2022, 11, 16, 17, 16), 'Clock Out': datetime.datetime(2022, 11, 16, 18, 14), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9666666666666667}
# 1111 = {'Clock In': datetime.datetime(2022, 11, 16, 18, 14), 'Clock Out': datetime.datetime(2022, 11, 16, 20, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.7666666666666666}
# 1112 = {'Clock In': datetime.datetime(2022, 11, 16, 20, 0), 'Clock Out': datetime.datetime(2022, 11, 16, 22, 5), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0833333333333335}
# 1113 = {'Clock In': datetime.datetime(2022, 11, 17, 12, 56), 'Clock Out': datetime.datetime(2022, 11, 17, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.06666666666666667}
# 1114 = {'Clock In': datetime.datetime(2022, 11, 17, 13, 0), 'Clock Out': datetime.datetime(2022, 11, 17, 15, 30), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.5}
# 1115 = {'Clock In': datetime.datetime(2022, 11, 17, 15, 30), 'Clock Out': datetime.datetime(2022, 11, 17, 16, 0), 'Task': 'Meeting', 'Notes': None, 'Event duration': 0.5}
# 1116 = {'Clock In': datetime.datetime(2022, 11, 17, 16, 0), 'Clock Out': datetime.datetime(2022, 11, 17, 17, 12), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.2}
# 1117 = {'Clock In': datetime.datetime(2022, 11, 17, 17, 12), 'Clock Out': datetime.datetime(2022, 11, 17, 18, 11), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9833333333333333}
# 1118 = {'Clock In': datetime.datetime(2022, 11, 17, 18, 11), 'Clock Out': datetime.datetime(2022, 11, 17, 20, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.8166666666666667}
# 1119 = {'Clock In': datetime.datetime(2022, 11, 17, 20, 0), 'Clock Out': datetime.datetime(2022, 11, 17, 22, 6), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.1}
# 1120 = {'Clock In': datetime.datetime(2022, 11, 18, 12, 59), 'Clock Out': datetime.datetime(2022, 11, 18, 13, 20), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.35}
# 1121 = {'Clock In': datetime.datetime(2022, 11, 18, 13, 20), 'Clock Out': datetime.datetime(2022, 11, 18, 13, 42), 'Task': 'Update PC', 'Notes': None, 'Event duration': 0.36666666666666664}
# 1122 = {'Clock In': datetime.datetime(2022, 11, 18, 13, 42), 'Clock Out': datetime.datetime(2022, 11, 18, 19, 2), 'Task': 'Tickets', 'Notes': None, 'Event duration': 5.333333333333333}
# 1123 = {'Clock In': datetime.datetime(2022, 11, 18, 19, 2), 'Clock Out': datetime.datetime(2022, 11, 18, 19, 59), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.95}
# 1124 = {'Clock In': datetime.datetime(2022, 11, 18, 19, 59), 'Clock Out': datetime.datetime(2022, 11, 18, 22, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0166666666666666}
# 1125 = {'Clock In': datetime.datetime(2022, 11, 21, 15, 27), 'Clock Out': datetime.datetime(2022, 11, 21, 19, 14), 'Task': 'Tickets', 'Notes': None, 'Event duration': 3.783333333333333}
# 1126 = {'Clock In': datetime.datetime(2022, 11, 21, 19, 14), 'Clock Out': datetime.datetime(2022, 11, 21, 20, 15), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.0166666666666666}
# 1127 = {'Clock In': datetime.datetime(2022, 11, 21, 20, 15), 'Clock Out': datetime.datetime(2022, 11, 22, 0, 39), 'Task': 'Tickets', 'Notes': None, 'Event duration': 4.4}
# 1128 = {'Clock In': datetime.datetime(2022, 11, 22, 15, 26), 'Clock Out': datetime.datetime(2022, 11, 22, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.5666666666666667}
# 1129 = {'Clock In': datetime.datetime(2022, 11, 22, 16, 0), 'Clock Out': datetime.datetime(2022, 11, 22, 17, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 1130 = {'Clock In': datetime.datetime(2022, 11, 22, 17, 0), 'Clock Out': datetime.datetime(2022, 11, 22, 18, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 1131 = {'Clock In': datetime.datetime(2022, 11, 22, 18, 0), 'Clock Out': datetime.datetime(2022, 11, 22, 19, 2), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0333333333333334}
# 1132 = {'Clock In': datetime.datetime(2022, 11, 22, 19, 2), 'Clock Out': datetime.datetime(2022, 11, 22, 19, 58), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.9333333333333333}
# 1133 = {'Clock In': datetime.datetime(2022, 11, 22, 19, 58), 'Clock Out': datetime.datetime(2022, 11, 23, 0, 35), 'Task': 'Tickets', 'Notes': None, 'Event duration': 4.616666666666666}
# 1134 = {'Clock In': datetime.datetime(2022, 11, 23, 15, 29), 'Clock Out': datetime.datetime(2022, 11, 23, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 0.5166666666666667}
# 1135 = {'Clock In': datetime.datetime(2022, 11, 23, 16, 0), 'Clock Out': datetime.datetime(2022, 11, 23, 17, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}
# 1136 = {'Clock In': datetime.datetime(2022, 11, 23, 17, 0), 'Clock Out': datetime.datetime(2022, 11, 23, 18, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.0}
# 1137 = {'Clock In': datetime.datetime(2022, 11, 23, 18, 0), 'Clock Out': datetime.datetime(2022, 11, 23, 19, 5), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0833333333333333}
# 1138 = {'Clock In': datetime.datetime(2022, 11, 23, 19, 5), 'Clock Out': datetime.datetime(2022, 11, 23, 20, 4), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9833333333333333}
# 1139 = {'Clock In': datetime.datetime(2022, 11, 23, 20, 4), 'Clock Out': datetime.datetime(2022, 11, 24, 0, 30), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.433333333333334}
# {'0': {'Clock In': datetime.datetime(2022, 1, 1, 15, 27), 'Clock Out': datetime.datetime(2022, 1, 1, 19, 30), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.05}, '1': {'Clock In': datetime.datetime(2022, 1, 1, 19, 30), 'Clock Out': datetime.datetime(2022, 1, 1, 20, 30), 'Task': 'Working Lunch', 'Notes': None, 'Event duration': 1.0}, '2': {'Clock In': datetime.datetime(2022, 1, 1, 20, 30), 'Clock Out': datetime.datetime(2022, 1, 2, 0, 41), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 4.183333333333334}, '3': {'Clock In': datetime.datetime(2022, 1, 3, 10, 56), 'Clock Out': datetime.datetime(2022, 1, 3, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.066666666666667}, '4': {'Clock In': datetime.datetime(2022, 1, 3, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 3, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}, '5': {'Clock In': datetime.datetime(2022, 1, 3, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 3, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}, '6': {'Clock In': datetime.datetime(2022, 1, 3, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 3, 18, 20), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.3333333333333335}, '7': {'Clock In': datetime.datetime(2022, 1, 3, 18, 20), 'Clock Out': datetime.datetime(2022, 1, 3, 19, 17), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.95}, '8': {'Clock In': datetime.datetime(2022, 1, 3, 19, 17), 'Clock Out': datetime.datetime(2022, 1, 3, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.7166666666666666}, '9': {'Clock In': datetime.datetime(2022, 1, 3, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 3, 22, 3), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.05}, '10': {'Clock In': datetime.datetime(2022, 1, 4, 10, 58), 'Clock Out': datetime.datetime(2022, 1, 4, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.033333333333333}, '11': {'Clock In': datetime.datetime(2022, 1, 4, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 4, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}, '12': {'Clock In': datetime.datetime(2022, 1, 4, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 4, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}, '13': {'Clock In': datetime.datetime(2022, 1, 4, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 4, 18, 6), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.1}, '14': {'Clock In': datetime.datetime(2022, 1, 4, 18, 6), 'Clock Out': datetime.datetime(2022, 1, 4, 19, 4), 'Task': 'Lunch', 'Notes': None, 'Event duration': 0.9666666666666667}, '15': {'Clock In': datetime.datetime(2022, 1, 4, 19, 4), 'Clock Out': datetime.datetime(2022, 1, 4, 21, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.9333333333333333}, '16': {'Clock In': datetime.datetime(2022, 1, 4, 21, 0), 'Clock Out': datetime.datetime(2022, 1, 4, 22, 14), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.2333333333333334}, '17': {'Clock In': datetime.datetime(2022, 1, 5, 11, 5), 'Clock Out': datetime.datetime(2022, 1, 5, 13, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 1.9166666666666667}, '18': {'Clock In': datetime.datetime(2022, 1, 5, 13, 0), 'Clock Out': datetime.datetime(2022, 1, 5, 14, 0), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 1.0}, '19': {'Clock In': datetime.datetime(2022, 1, 5, 14, 0), 'Clock Out': datetime.datetime(2022, 1, 5, 16, 0), 'Task': 'Tickets', 'Notes': None, 'Event duration': 2.0}, '20': {'Clock In': datetime.datetime(2022, 1, 5, 16, 0), 'Clock Out': datetime.datetime(2022, 1, 5, 18, 18), 'Task': 'Monitor Queue', 'Notes': None, 'Event duration': 2.3}, '21': {'Clock In': datetime.datetime(2022, 1, 5, 18, 18), 'Clock Out': datetime.datetime(2022, 1, 5, 19, 18), 'Task': 'Lunch', 'Notes': None, 'Event duration': 1.0}, '22': {'Clock In': datetime.datetime(2022, 1, 5, 19, 18), 'Clock Out': datetime.datetime(2022, 1, 5, 21, 0), 'Task': 'Monitor Queue', 'Notes': None ...
